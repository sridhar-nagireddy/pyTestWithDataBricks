# %%
# %pip install chispa
# %pip install pytest-html

# %%
dbutils.library.restartPython()

# %%
# Run Pytests which are developed locally 
# But run them from NoteBook

import os
import sys
import pytest
from pyspark.sql import SparkSession
import builtins
import test_context






# Disable bytecode generation before any other imports
sys.dont_write_bytecode = True
os.environ["PYTHONDONTWRITEBYTECODE"] = "1"
os.chdir("/Workspace/Repos/sridharnagireddy@gmail.com/pyTestWithDataBricks")

# spark_session = spark
# builtins.spark_session = spark

test_context.spark_session = spark

pytest.main([
    "tests",
    "-v",
    "-p", "no:cacheprovider",
    "--html=/tmp/report.html",
    "--self-contained-html"
])
displayHTML(open("/tmp/report.html").read())
